# %% [markdown]
# # Week 12 Assignment - Simulating Dispersal with Objects

# %% [markdown]
# For this week's assignment, we're going to revisit the dispersal simulation that we worked on in Week 8. However, this time, we're going to use object-oriented programming. Specifically, we'll create two kinds of custom objects: `individual`s and `population`s.
#
# Each `individual` will have 3 attributes (an id number, a x-axis position, and a y-position) and 3 methods (a constructor, a method to move its position by 1 unit, and a method to print its coordinate location as x,y).
#
# Each `population` will have 2 attributes (a list of `individual`s in the `population` and a size for its map) and 4 methods (a constructor, a method to move each `individual` in the `population` 1 unit, a method to list the coordinate locations of all `individuals` in the `population`, and a method to display the locations of all `individual`s in the `population` as a scatter plot).
#
# More details are provided below.

# %%
# Import necessary modules

import random
from copy import copy
import matplotlib.pyplot as plt

# %%
# Define the individual class

class individual:
    # Add a docstring
    ''' function for class that describes individual with three features'''
    def __init__(self,id="1",x=0.0,y=0.0): # Add default values for id, x, and y
        # Add a docstring
        '''constructor initializing the 3 attributles based on the given values'''
        # The constructor should initialize the 3 attributes based on the values
        # passed as arguments to the constructor.
        self.id= id
        self.x = x
        self.y = y
    
    def move(self): # Add necessary arguments
        # Add a docstring
        '''function to move individual's position by one unit up, down, left, or right'''
        # Similar to the code from week 8, the code in this method should cause an
        # individual to move one unit up, down, left, or right (chosen randomly).
        # The x and y coordinates for this individual should be modified accordingly.
        direction = ["u","d","l","r"]
        move = random.choice(direction) #function to randomly change position/direction
        if move == "u": #change position based on direction
            self.y +=1
        elif move == "d":
            self.y -=1
        elif move == "l":
            self.x -=1
        elif move == "r":
            self.x +=1
        else:
            print("Error message")
    def printLocation(self): # Add necessary arguments
        # Add a docstring
        ''' This function will print specific location for x and y'''
        # This method should print a text description of the 
        # individual's id and location (x,y).
        print("ID:{} Location({},{})".format(self.id,self.x,self.y))

# %%
# Define the population class

class population:
    # Add a docstring
    '''function will characterize class population'''
    
    def __init__(self,mapSize=40,popSize=80): # Add default values.
        # Add a docstring
        '''function to recognize two features of mapSize and popSize'''
        # This constructor should create a list of individuals in the population. The 
        # number of individuals should be equal to popSize and each individual should have
        # a unique id. The constructor should also record the mapSize as an attribute.
        self.mapSize = mapSize
        self.popSize = popSize
        self.ind=[] #function to create list of individuals in the population
        for i in range(popSize):
            self.ind.append(individual(id = i+1)) #individual's ID

    def move(self): # Add necessary arguments
        # Add a docstring
        '''function to move each individual in the population one unit up'''
        # The code in this method should use a for loop and cause each individual to 
        # move one unit up, down, left, or right. This code should call the .move() method
        # of each individual.
        for i in self.ind:
            i.move()
        
    def listLocations(self): # Add necessary arguments
        # Add a docstring

        '''this function will print descriptions of each individual's location'''
        # The code in this method should use a for loop to print a text description of
        # each individual's location. This code should call the .printLocation() method
        # of each individual.
        for i in self.ind:
            i.printLocation()
        
    def draw(self): # Add necessary arguments
        # Add a docstring
        '''this function will creat a scatter plot for individuals in the population'''        
        # The code in this method should use the .plot() method from pyplot to 
        # create a scatterplot showing the locations of all individuals in this
        # population. The length of the x- and y-axes should each by mapSize.
        for i in self.ind:
            plt.scatter(x= i.x, y= i.y)
        plt.title('Locations')
        plt.grid(True)
        plt.show()

# %% [markdown]
# Now that we've created the individual and population classes, let's use them to create populations of individuals and watch them disperse across a map.

# %%
# Create a new population with default values
NewPop= population()
# Assign the number of time steps that individuals will move
moves=20
# Use a for loop to simulate the movement of individuals for the specified number of steps.
for i in range(moves):
    NewPop.move()
# Use the .draw() method of the population to draw the map.
NewPop.draw()
# Use the .listLocations() method to list the locations of all individuals in the population.
NewPop.listLocations()
# Out:
# ID:1 Location(-4.0,6.0)
# ID:2 Location(4.0,-6.0)
# ID:3 Location(-1.0,3.0)
# ID:4 Location(-1.0,1.0)
# ID:5 Location(-4.0,-2.0)
# ID:6 Location(-5.0,-3.0)
# ID:7 Location(-6.0,0.0)
# ID:8 Location(4.0,-2.0)
# ID:9 Location(0.0,4.0)
# ID:10 Location(1.0,5.0)
# ID:11 Location(-3.0,-3.0)
# ID:12 Location(-6.0,0.0)
# ID:13 Location(2.0,4.0)
# ID:14 Location(3.0,3.0)
# ID:15 Location(1.0,1.0)
# ID:16 Location(-1.0,1.0)
# ID:17 Location(2.0,-2.0)
# ID:18 Location(6.0,4.0)
# ID:19 Location(-1.0,5.0)
# ID:20 Location(-4.0,0.0)
# ID:21 Location(2.0,8.0)
# ID:22 Location(2.0,-4.0)
# ID:23 Location(3.0,3.0)
# ID:24 Location(-2.0,-2.0)
# ID:25 Location(2.0,-2.0)
# ID:26 Location(-1.0,3.0)
# ID:27 Location(2.0,2.0)
# ID:28 Location(-2.0,2.0)
# ID:29 Location(3.0,-3.0)
# ID:30 Location(-1.0,-1.0)
# ID:31 Location(-1.0,1.0)
# ID:32 Location(-2.0,2.0)
# ID:33 Location(2.0,-2.0)
# ID:34 Location(-4.0,-4.0)
# ID:35 Location(6.0,2.0)
# ID:36 Location(0.0,-4.0)
# ID:37 Location(-2.0,4.0)
# ID:38 Location(-7.0,1.0)
# ID:39 Location(-1.0,-3.0)
# ID:40 Location(3.0,5.0)
# ID:41 Location(0.0,2.0)
# ID:42 Location(1.0,3.0)
# ID:43 Location(-2.0,0.0)
# ID:44 Location(2.0,-2.0)
# ID:45 Location(-1.0,-1.0)
# ID:46 Location(1.0,-7.0)
# ID:47 Location(3.0,1.0)
# ID:48 Location(-4.0,0.0)
# ID:49 Location(1.0,3.0)
# ID:50 Location(3.0,3.0)
# ID:51 Location(8.0,2.0)
# ID:52 Location(-1.0,-5.0)
# ID:53 Location(-4.0,-6.0)
# ID:54 Location(2.0,4.0)
# ID:55 Location(2.0,0.0)
# ID:56 Location(-6.0,0.0)
# ID:57 Location(-3.0,7.0)
# ID:58 Location(3.0,3.0)
# ID:59 Location(-3.0,-7.0)
# ID:60 Location(3.0,5.0)
# ID:61 Location(3.0,1.0)
# ID:62 Location(-1.0,1.0)
# ID:63 Location(2.0,4.0)
# ID:64 Location(-2.0,2.0)
# ID:65 Location(-4.0,2.0)
# ID:66 Location(6.0,-4.0)
# ID:67 Location(0.0,-4.0)
# ID:68 Location(6.0,2.0)
# ID:69 Location(0.0,2.0)
# ID:70 Location(3.0,-3.0)
# ID:71 Location(2.0,0.0)
# ID:72 Location(1.0,-1.0)
# ID:73 Location(3.0,1.0)
# ID:74 Location(-3.0,-7.0)
# ID:75 Location(-5.0,-5.0)
# ID:76 Location(-4.0,2.0)
# ID:77 Location(0.0,0.0)
# ID:78 Location(0.0,-8.0)
# ID:79 Location(-4.0,0.0)
# ID:80 Location(-1.0,-1.0)

# %%
# Try creating a new population, simulating the movement of individuals, drawing a map,
# and listing the location of individuals, but provide non-default values for the mapSize
# and popSize of the population. Also, increase the number of time steps that individuals move.

#Function will create a new population
NewPop1=population(mapSize=25,popSize=50)
#number of time steps that individual will move
moves=20
#use a for loop to stimulate the movement of individuals for the specified number of steps
for i in range(moves):
    NewPop1.move()
#Use the .draw() method of the population to draw the map
NewPop1.draw()
#Use the list .listLocations() method to list the locations of all individuals in the population
NewPop1.listLocations()
# Out:
# ID:1 Location(-6.0,2.0)
# ID:2 Location(4.0,2.0)
# ID:3 Location(3.0,-3.0)
# ID:4 Location(5.0,1.0)
# ID:5 Location(-6.0,4.0)
# ID:6 Location(2.0,4.0)
# ID:7 Location(-2.0,-2.0)
# ID:8 Location(5.0,3.0)
# ID:9 Location(4.0,2.0)
# ID:10 Location(4.0,2.0)
# ID:11 Location(0.0,-4.0)
# ID:12 Location(-1.0,-5.0)
# ID:13 Location(-3.0,-5.0)
# ID:14 Location(-4.0,4.0)
# ID:15 Location(-1.0,-5.0)
# ID:16 Location(0.0,-8.0)
# ID:17 Location(4.0,-2.0)
# ID:18 Location(-3.0,-5.0)
# ID:19 Location(3.0,1.0)
# ID:20 Location(-4.0,4.0)
# ID:21 Location(3.0,-1.0)
# ID:22 Location(1.0,-1.0)
# ID:23 Location(-5.0,5.0)
# ID:24 Location(-3.0,-3.0)
# ID:25 Location(7.0,5.0)
# ID:26 Location(5.0,1.0)
# ID:27 Location(0.0,-2.0)
# ID:28 Location(-3.0,-1.0)
# ID:29 Location(-1.0,3.0)
# ID:30 Location(-1.0,-1.0)
# ID:31 Location(-1.0,1.0)
# ID:32 Location(0.0,-6.0)
# ID:33 Location(-2.0,0.0)
# ID:34 Location(5.0,7.0)
# ID:35 Location(-2.0,-2.0)
# ID:36 Location(1.0,1.0)
# ID:37 Location(6.0,-2.0)
# ID:38 Location(-2.0,4.0)
# ID:39 Location(-1.0,-7.0)
# ID:40 Location(2.0,2.0)
# ID:41 Location(0.0,0.0)
# ID:42 Location(2.0,-2.0)
# ID:43 Location(-1.0,1.0)
# ID:44 Location(0.0,2.0)
# ID:45 Location(-4.0,-2.0)
# ID:46 Location(-3.0,3.0)
# ID:47 Location(2.0,-4.0)
# ID:48 Location(-1.0,-3.0)
# ID:49 Location(2.0,-4.0)
# ID:50 Location(1.0,1.0)
